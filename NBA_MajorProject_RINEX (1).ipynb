# %%
#Import the libraries
import pandas as pd
import numpy as np

# %%
#Creating the dataframe from the csv file
df = pd.read_csv('nba.csv')
df
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25    6-2     180
# 1      Jae Crowder  Boston Celtics      99       SF   25    6-6     235
# 2     John Holland  Boston Celtics      30       SG   27    6-5     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22    6-5     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29   6-10     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20   6-10     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26    6-3     203
# 454      Raul Neto       Utah Jazz      25       PG   24    6-1     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26    7-3     256
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#Filtering the dataset

#Removing the Null Values
print(df.isnull().sum())
df.dropna(how='all',inplace=True)
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
#Gathering the information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    int64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    int64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    int64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
#Changing the datatype of necessary columns
#schema = {'Position':'category'}
#df = df.astype(schema)

# %%
#Describing the dataset
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
#Using aggregation functions to find maximum, minimun, mean & sum
print(df['Age'].min())
print(df['Age'].max())
print(df['Age'].mean())
print(df['Age'].sum())
# Out:
# 19
# 40
# 26.938730853391686
# 12311

# %%
#Getting the Size of the dataset
df.size
# Out:
# 4113

# %%
#Finding the unique values from given column
print(pd.unique(df['Team']),'\n')
print(pd.unique(df['Position']))
# Out:
# ['Boston Celtics' 'Brooklyn Nets' 'New York Knicks' 'Philadelphia 76ers'
#  'Toronto Raptors' 'Golden State Warriors' 'Los Angeles Clippers'
#  'Los Angeles Lakers' 'Phoenix Suns' 'Sacramento Kings' 'Chicago Bulls'
#  'Cleveland Cavaliers' 'Detroit Pistons' 'Indiana Pacers'
#  'Milwaukee Bucks' 'Dallas Mavericks' 'Houston Rockets'
#  'Memphis Grizzlies' 'New Orleans Pelicans' 'San Antonio Spurs'
#  'Atlanta Hawks' 'Charlotte Hornets' 'Miami Heat' 'Orlando Magic'
#  'Washington Wizards' 'Denver Nuggets' 'Minnesota Timberwolves'
#  'Oklahoma City Thunder' 'Portland Trail Blazers' 'Utah Jazz']
#
# ['PG' 'SF' 'SG' 'PF' 'C']

# %%
#Finding the value counts using the group by function
df['Age'].value_counts()
# Out:
# 24    47
# 25    45
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: Age, dtype: int64

# %%
#Checking memeory usage
print(df['Position'].memory_usage())
# Out:
# 3784

# %%
#The way to find the missing value count
pd.isna(df).sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
#How many rows are present in the dataset?
df.shape[0]
# Out:
# 457

# %%
#Select all the rows excluding the bottom 157 rows using head() function. What is the salary of the last row?
df.head(-157)
#Salary of the last row is 2814000.0
# Out:
#               Name               Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley     Boston Celtics       0       PG   25    6-2     180
# 1      Jae Crowder     Boston Celtics      99       SF   25    6-6     235
# 2     John Holland     Boston Celtics      30       SG   27    6-5     205
# 3      R.J. Hunter     Boston Celtics      28       SG   22    6-5     185
# 4    Jonas Jerebko     Boston Celtics       8       PF   29   6-10     231
# ..             ...                ...     ...      ...  ...    ...     ...
# 295  Kyle Anderson  San Antonio Spurs       1       SF   22    6-9     230
# 296    Matt Bonner  San Antonio Spurs      15        C   36   6-10     235
# 297     Boris Diaw  San Antonio Spurs      33        C   34    6-8     250
# 298     Tim Duncan  San Antonio Spurs      21        C   40   6-11     250
# 299  Manu Ginobili  San Antonio Spurs      20       SG   38    6-6     205
#
#                College     Salary
# ...

# %%
#Select all the rows excluding the bottom 17 rows using head() function. What is the salary of the last row?
df.head(-17)
#Salary of the last row is 1415520.0
# Out:
#                Name                    Team  Number Position  Age Height  \
# 0     Avery Bradley          Boston Celtics       0       PG   25    6-2
# 1       Jae Crowder          Boston Celtics      99       SF   25    6-6
# 2      John Holland          Boston Celtics      30       SG   27    6-5
# 3       R.J. Hunter          Boston Celtics      28       SG   22    6-5
# 4     Jonas Jerebko          Boston Celtics       8       PF   29   6-10
# ..              ...                     ...     ...      ...  ...    ...
# 435  Meyers Leonard  Portland Trail Blazers      11       PF   24    7-1
# 436  Damian Lillard  Portland Trail Blazers       0       PG   25    6-3
# 437   C.J. McCollum  Portland Trail Blazers       3       SG   24    6-4
# 438    Luis Montero  Portland Trail Blazers      44       SG   23    6-7
# 439   Mason Plumlee  Portland Trail Blazers      24        C   26   6-11
#
#      Weight            College     Salary
# 0       180              Texas  7730337.0
# ...

# %%
#Select all the rows excluding the top 17 rows using tail() function. What is the salary of the first row?
df.tail(-17)
#Salary is 1500000.0
# Out:
#                         Name           Team  Number Position  Age Height  \
# 17           Wayne Ellington  Brooklyn Nets      21       SG   28    6-4
# 18   Rondae Hollis-Jefferson  Brooklyn Nets      24       SG   21    6-7
# 19              Jarrett Jack  Brooklyn Nets       2       PG   32    6-3
# 20            Sergey Karasev  Brooklyn Nets      10       SG   22    6-7
# 21           Sean Kilpatrick  Brooklyn Nets       6       SG   26    6-4
# ..                       ...            ...     ...      ...  ...    ...
# 452               Trey Lyles      Utah Jazz      41       PF   20   6-10
# 453             Shelvin Mack      Utah Jazz       8       PG   26    6-3
# 454                Raul Neto      Utah Jazz      25       PG   24    6-1
# 455             Tibor Pleiss      Utah Jazz      21        C   26    7-3
# 456              Jeff Withey      Utah Jazz      24        C   26    7-0
#
#      Weight         College     Salary
# 17      200  North Carolina  1500000.0
# ...

# %%
#How many NaN values are present in the salary column?
df['Salary'].isna().sum()
# Out:
# 11

# %%
#How many NaN values are present in the college column?
df['College'].isna().sum()
# Out:
# 84

# %%
#Drop the rows (25,72,63) from the dataset. What's the average age of players after dropping rows?
x = df.drop([25,72,63])
x['Age'].mean()
# Out:
# 26.916299559471366

# %%
#Rename column 'Number' to 'Chest_Number' and 'Weight' to 'Weight(lbs)' in the dataset.
df.rename(columns={'Number':'Chest_Number','Weight':'Weight(lbs)'}, inplace=True)
df
# Out:
#               Name            Team  Chest_Number Position  Age Height  \
# 0    Avery Bradley  Boston Celtics             0       PG   25    6-2
# 1      Jae Crowder  Boston Celtics            99       SF   25    6-6
# 2     John Holland  Boston Celtics            30       SG   27    6-5
# 3      R.J. Hunter  Boston Celtics            28       SG   22    6-5
# 4    Jonas Jerebko  Boston Celtics             8       PF   29   6-10
# ..             ...             ...           ...      ...  ...    ...
# 452     Trey Lyles       Utah Jazz            41       PF   20   6-10
# 453   Shelvin Mack       Utah Jazz             8       PG   26    6-3
# 454      Raul Neto       Utah Jazz            25       PG   24    6-1
# 455   Tibor Pleiss       Utah Jazz            21        C   26    7-3
# 456    Jeff Withey       Utah Jazz            24        C   26    7-0
#
#      Weight(lbs)            College     Salary
# 0            180              Texas  7730337.0
# ...

# %%
#Find the name of the player with highest salary

#Method 1
df.sort_values(by = 'Salary',ascending=False)

#Method 2
df['Salary'].max()
df[df['Salary']==25000000.0]
# Out:
#             Name                Team  Chest_Number Position  Age Height  \
# 109  Kobe Bryant  Los Angeles Lakers            24       SF   37    6-6
#
#      Weight(lbs) College      Salary
# 109          212     NaN  25000000.0

# %%
#Find the name of the player with the lowest salary
df.sort_values(by = 'Salary')
# Out:
#                        Name                    Team  Chest_Number Position  \
# 32   Thanasis Antetokounmpo         New York Knicks            43       SF
# 291         Orlando Johnson    New Orleans Pelicans             0       SG
# 130            Phil Pressey            Phoenix Suns            25       PG
# 135           Alan Williams            Phoenix Suns            15        C
# 175            Jordan McRae     Cleveland Cavaliers            12       SG
# ..                      ...                     ...           ...      ...
# 273          Alex Stepheson       Memphis Grizzlies            35       PF
# 350           Briante Weber              Miami Heat            12       PG
# 353           Dorell Wright              Miami Heat            11       SF
# 397            Axel Toupane          Denver Nuggets             6       SG
# 409              Greg Smith  Minnesota Timberwolves             4       PF
#
#      Age Height  Weight(lbs)                College    Salary
# ...

# %%
#Find the number of players weighting above 180 pounds
weight = df['Weight(lbs)']
con = (weight>180)
con.sum()
# Out:
# 431

# %%
#The count of all the players with height less than 6-2
height = df['Height']
c = (height<"6-2")
c.sum()
# Out:
# 117

# %%
#All the players with age more than 35 and position must be of 'PF' position
age = df['Age']
pos = df['Position']
c1 = (age>35) & (pos=='PF')
df[c1]
c1.sum()
# Out:
# 6

# %%
#Which team value has highest occurance in the data?
team = df['Team']
team.value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Boston Celtics            15
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Dallas Mavericks          15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Utah Jazz                 15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64

# %%
#Which team has the highest number of youngest players (Age less than or equal to 25) playing in position 'PF' or "SF"
df[(df['Age']<=25) & (df['Position'].isin(['PF','SF']))]["Team"].value_counts()
# Out:
# Chicago Bulls             6
# Philadelphia 76ers        5
# Portland Trail Blazers    5
# Houston Rockets           5
# Milwaukee Bucks           5
# New York Knicks           4
# Memphis Grizzlies         4
# Los Angeles Lakers        4
# Detroit Pistons           4
# Indiana Pacers            4
# Sacramento Kings          3
# Golden State Warriors     3
# Minnesota Timberwolves    3
# Washington Wizards        2
# Boston Celtics            2
# San Antonio Spurs         2
# Oklahoma City Thunder     2
# Orlando Magic             2
# Utah Jazz                 2
# New Orleans Pelicans      2
# Brooklyn Nets             2
# Toronto Raptors           2
# Atlanta Hawks             1
# Charlotte Hornets         1
# Miami Heat                1
# Denver Nuggets            1
# Phoenix Suns              1
# Los Angeles Clippers      1
# Dallas Mavericks          1
# Name: Team, dtype: int64

# %%
#What is the sum of the salaries of all the players with chest number 41?
df[df['Chest_Number']==41]["Salary"].sum()
# Out:
# 22264701.0

# %%
#What is the average salary received by players who are 23 or younger in team 'Chicago Bulls'?
df[(df['Age']<=23) & (df['Team']=='Chicago Bulls')]['Salary'].mean()
# Out:
# 958126.5

# %%
#What is the average age of players from rows 201 & 250?
ro = df.iloc[201:251]
ro['Age'].mean()
# Out:
# 26.62

# %%
#What is the average weight of players from rows 350 & 400?
we = df.iloc[350:401]
we['Weight(lbs)'].mean()
# Out:
# 217.9607843137255

# %%
#What is the average age of players in team Boston Celtics?
df[(df['Team']=='Boston Celtics')]['Age'].mean()
# Out:
# 24.733333333333334

# %%
#What is the weight in kgs for the 112th record (111th index)?

#Creating a new column
df["Weight(kgs)"] = df['Weight(lbs)']/2.2046
#df
df.iloc[111]
# Out:
# Name                   Roy Hibbert
# Team            Los Angeles Lakers
# Chest_Number                    17
# Position                         C
# Age                             29
# Height                         7-2
# Weight(lbs)                    270
# College                 Georgetown
# Salary                  15592217.0
# Weight(kgs)             122.471197
# Name: 111, dtype: object

# %%
#Count of the players who're from Texas
df[df['College']=='Texas']['College'].count()
# Out:
# 9

# %%
#Average salary of the players who're from Texas
df[df['College']=='Texas']['Salary'].mean()
# Out:
# 8968001.111111112

# %%
#Find the total money spent by each team on their players
df.groupby(by='Team')["Salary"].sum().sort_values()
# Out:
# Team
# Philadelphia 76ers         30992894.0
# Portland Trail Blazers     48301818.0
# Brooklyn Nets              52528475.0
# Boston Celtics             58541068.0
# Minnesota Timberwolves     59709697.0
# Denver Nuggets             60121930.0
# Orlando Magic              60161470.0
# Utah Jazz                  63060091.0
# Phoenix Suns               63445135.0
# Indiana Pacers             66751826.0
# Detroit Pistons            67168263.0
# Milwaukee Bucks            69603517.0
# Toronto Raptors            71117611.0
# Dallas Mavericks           71198732.0
# Sacramento Kings           71683666.0
# Los Angeles Lakers         71770431.0
# Atlanta Hawks              72902950.0
# New York Knicks            73303898.0
# Houston Rockets            75283021.0
# Washington Wizards         76328636.0
# Memphis Grizzlies          76550880.0
# Charlotte Hornets          78340920.0
# Miami Heat                 82515673.0
# New Orleans Pelicans       82750774.0
# ...

# %%
#Which College students has the highest aggregate salary?
df.groupby(by='College')['Salary'].sum().sort_values()
# Out:
# College
# Rhode Island                 0.0
# Detroit                      0.0
# Boston University            0.0
# UC Santa Barbara        139119.0
# Iowa State              169883.0
#                         ...
# Florida               65335712.0
# Duke                  79979176.0
# Texas                 80712010.0
# UCLA                  81259810.0
# Kentucky             137706556.0
# Name: Salary, Length: 118, dtype: float64

# %%
#Which Position has the maximum (individual) salary?
df.groupby(by='Position')['Salary'].max().sort_values()
# Out:
# Position
# SG    20000000.0
# PG    21468695.0
# PF    22192730.0
# C     22359364.0
# SF    25000000.0
# Name: Salary, dtype: float64

# %%
#Find the team with the highest salaried position
df.groupby(by=['Team','Position'])['Salary'].max().sort_values()
# Out:
# Team                 Position
# Orlando Magic        SF            845059.0
# Sacramento Kings     PF            845059.0
# Miami Heat           C             981348.0
# Philadelphia 76ers   SF           1000000.0
# Denver Nuggets       SG           1584480.0
#                                     ...
# Miami Heat           PF          22192730.0
# Houston Rockets      C           22359364.0
# New York Knicks      SF          22875000.0
# Cleveland Cavaliers  SF          22970500.0
# Los Angeles Lakers   SF          25000000.0
# Name: Salary, Length: 149, dtype: float64

# %%
#Filter all the players with age greater than 35, then, find the heaviest player as well as the position of the player
con = df[df['Age']>35]
con.groupby(by=['Team','Position'])['Weight(lbs)'].max().sort_values(ascending=False)
# Out:
# Team                    Position
# Los Angeles Lakers      SF          260
# Philadelphia 76ers      PF          254
# San Antonio Spurs       C           250
# Oklahoma City Thunder   C           250
# Dallas Mavericks        PF          245
# Memphis Grizzlies       PF          245
# Minnesota Timberwolves  PF          240
# Toronto Raptors         PF          240
# Miami Heat              PF          235
# Los Angeles Clippers    SF          235
# Sacramento Kings        SF          228
# Memphis Grizzlies       SF          226
#                         SG          220
# Denver Nuggets          SG          218
# Minnesota Timberwolves  SF          212
# San Antonio Spurs       SG          205
#                         PG          200
# Los Angeles Clippers    SG          195
#                         PG          185
# Houston Rockets         SG          185
# Detroit Pistons         PG          172
# Name: Weight(lbs), dtype: int64

# %%
df['Salary'].sort_values(ascending=True)
# Out:
# 32      30888.0
# 291     55722.0
# 130     55722.0
# 135     83397.0
# 175    111196.0
#          ...
# 273         NaN
# 350         NaN
# 353         NaN
# 397         NaN
# 409         NaN
# Name: Salary, Length: 457, dtype: float64

# %%
#Data Visualization
import matplotlib.pyplot as plt

# %%
#Pie Chart for The Salary & Position
x = ['C','PF','PG','SF','SG']
ex = [0,0,0,0,0.1]
plt.style.use('seaborn-dark-palette')
plt.title('The Salary & Position Pie Chart')
y = df.groupby(by='Position')['Salary'].count()
plt.pie(y,labels=x,autopct='%1.1f%%',explode=ex)
plt.show()
# Out:
# <ipython-input-54-b606179a874d>:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-dark-palette')

# %%
#Using a bar graph to visualise The Position & Weight Comparison

plt.figure(figsize = (8, 3))
x = ['C','PF','PG','SF','SG']
plt.title('The Position & Weight Comparison',fontsize=15,color='gray',fontweight="bold")
y = df.groupby(by='Position')['Weight(lbs)'].count()
plt.xlabel('Positions')
plt.ylabel('Weight (in lbs)')
plt.style.use('ggplot')
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center',color='black')
plt.bar(x,y,color='maroon',edgecolor='yellow',alpha=0.8,width=0.5)
addlabels(x, y)
plt.show()

# %%
#Using a bar graph to visualise The College Count
plt.figure(figsize = (10, 5))
y = df[(df['College'].isin(['Texas','Kansas', 'Memphis', 'LSU','UCLA']))]["College"].value_counts()
x = ['Kansas','UCLA','Texas','LSU','Memphis']
plt.title('The College Count',fontsize=15,fontweight="bold")
plt.xlabel('College Name')
plt.ylabel('The Count')
plt.style.use('dark_background')
plt.ylim(0,20)
plt.bar(x,y,color='salmon',edgecolor='white',alpha=0.8)
plt.show()
